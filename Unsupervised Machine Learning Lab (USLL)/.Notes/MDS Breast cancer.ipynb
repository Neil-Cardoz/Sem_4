# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.datasets import load_breast_cancer

# %%
X = load_breast_cancer().data
y = load_breast_cancer().target

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
from sklearn.metrics import pairwise_distances
pairwise_X = pairwise_distances(X, metric='euclidean')
pairwise_X
# Out:
# array([[ 0.        , 10.31849715,  6.77763352, ..., 11.82848346,
#          6.97565122, 16.46384957],
#        [10.31849715,  0.        ,  5.0320153 , ...,  4.98423172,
#         10.89864277, 10.18812963],
#        [ 6.77763352,  5.0320153 ,  0.        , ...,  6.1529742 ,
#          6.92728594, 12.35436322],
#        ...,
#        [11.82848346,  4.98423172,  6.1529742 , ...,  0.        ,
#         10.55170316,  8.10241293],
#        [ 6.97565122, 10.89864277,  6.92728594, ..., 10.55170316,
#          0.        , 16.67463275],
#        [16.46384957, 10.18812963, 12.35436322, ...,  8.10241293,
#         16.67463275,  0.        ]])

# %%
from sklearn.manifold import MDS
mds = MDS(n_components=2, dissimilarity='precomputed', random_state=0)
X_mds = mds.fit_transform(pairwise_X)

# %%
plt.scatter(x=X_mds[:, 0], y=X_mds[:, 1],  alpha=0.75)

plt.xlabel("MDS1")
plt.ylabel("MDS2")
plt.show()
